# %% [markdown]
# # H1 My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jose Miro Quesada

# %% [markdown]
# *I am interested in data science to make informed decisions. Also, to know more.

# %% [markdown]
# ######my code will print "hello world"

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# 1. jose
# 2. miro
# 3. quesada
#
# This site was built using [IBM Watson](https://ibm.com/)
#
# ![This is an image](https://myoctocat.com/assets/images/base-octocat.svg)
